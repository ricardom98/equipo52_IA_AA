# %% [markdown]
# <a href="https://colab.research.google.com/github/ricardom98/equipo52_IA_AA/blob/main/MNA_IAyAA_semana_6_Actividad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Maestría en Inteligencia Artificial Aplicada**
# ##**Curso: Inteligencia Artificial y Aprendizaje Automático**
# ###Tecnológico de Monterrey
# ###Prof Luis Eduardo Falcón Morales
#
# ## **Adtividad de la Semana 6**
# ###**Árboles de decisión y bosque aleatorio.**

# %% [markdown]
# **Nombres y matrículas de los integrantes del equipo:**
#
# *
# *
# *
# *
# *

# %% [markdown]
# En cada sección deberás incluir todas las líneas de código necesarias para responder a cada uno de los ejercicios.

# %%
# Incluye aquí todos módulos, librerías y paquetes que requieras.
import numpy as np
import pandas as pd

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier 

from sklearn.datasets import load_iris

from sklearn.model_selection import train_test_split 
from sklearn.metrics import confusion_matrix

import matplotlib.pyplot as plt

# To create our Decision Tree Graph:
from sklearn import tree
import pydotplus 
from IPython.display import Image

from sklearn.ensemble import RandomForestClassifier

#from sklearn.datasets import load_iris
import sklearn.datasets

# %% [markdown]
# #**Ejercicio-1.**

# %%
url_test = 'https://raw.githubusercontent.com/ricardom98/equipo52_IA_AA/main/test.csv'
url_train = 'https://raw.githubusercontent.com/ricardom98/equipo52_IA_AA/main/train.csv'


df_train = pd.read_csv(url_train, sep=",") #Este archivo está separado por comas
df_test = pd.read_csv(url_test, sep=",") 

df = df_train.copy()

df = df.append(df_test).sample(frac=1).reset_index(drop=True) #Se hizo la unión de los archivos df_test y df_train para tener el dataset completo y se hizo un 'barajeo' de los sets.
df.describe()
# Out:
#                 Id     laufkont     laufzeit       moral         verw  \
# count  1000.000000  1000.000000  1000.000000  1000.00000  1000.000000
# mean    499.500000     2.577000    20.903000     2.54500     2.828000
# std     288.819436     1.257638    12.058814     1.08312     2.744439
# min       0.000000     1.000000     4.000000     0.00000     0.000000
# 25%     249.750000     1.000000    12.000000     2.00000     1.000000
# 50%     499.500000     2.000000    18.000000     2.00000     2.000000
# 75%     749.250000     4.000000    24.000000     4.00000     3.000000
# max     999.000000     4.000000    72.000000     4.00000    10.000000
#
#              hoehe     sparkont      beszeit         rate      famges  ...  \
# count   1000.00000  1000.000000  1000.000000  1000.000000  1000.00000  ...
# mean    3271.24800     2.105000     3.384000     2.973000     2.68200  ...
# std     2822.75176     1.580023     1.208306     1.118715     0.70808  ...
# ...

# %%
df_copy = df.copy()
translated_cols = ["id", "status", "duration", "credit_history", "purpose", "amount", "savings", 
                   "employment_duration", "installment_rate", "personal_status_sex", 
                   "other_debtors", "present_residence", "property", "age", "other_installment_plans", "housing",
                   "number_credits", "job", "people_liable", "telephone", "foreign_worker", "credit_risk"]

df_copy.columns = translated_cols
df_copy.head()
# Out:
#     id  status  duration  credit_history  purpose  amount  savings  \
# 0  988       1        18               2        0     976        1
# 1  946       4        10               2        2    2210        1
# 2  166       4        30               4        3    5771        1
# 3  379       4        30               4        3    6742        5
# 4  971       2        27               0        9    8318        1
#
#    employment_duration  installment_rate  personal_status_sex  ...  property  \
# 0                    2                 1                    2  ...         3
# 1                    3                 2                    3  ...         1
# 2                    4                 4                    2  ...         3
# 3                    4                 2                    3  ...         2
# 4                    5                 2                    2  ...         4
#
#    age  other_installment_plans  housing  number_credits  job  people_liable  \
# ...

# %% [markdown]
# #**Ejercicio-2.**

# %% [markdown]
# #**Ejercicio-3.**

# %%
None

# %% [markdown]
# #**Ejercicio-4.**

# %%
None

# %% [markdown]
# #**Ejercicio-5.**

# %%
None

# %% [markdown]
# #**Ejercicio-6.**

# %%
None

# %% [markdown]
# ###**Fin de la Actividad de la semana 6.**
